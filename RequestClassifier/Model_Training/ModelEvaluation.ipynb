# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Test Data

# %%
test_data_path=os.path.join(".","Data","final_test_data.csv")

# %%
test_data=pd.read_csv(test_data_path)

# %%
test_data
# Out:
#        duration  src_bytes  dst_bytes  wrong_fragment  urgent  count  \
# 0             0          0          0               0       0    136
# 1             2      12983          0               0       0      1
# 2             0         20          0               0       0      1
# 3             1          0         15               0       0      1
# 4             0        267      14515               0       0      4
# ...         ...        ...        ...             ...     ...    ...
# 22538         0        794        333               0       0      1
# 22539         0        317        938               0       0      2
# 22540         0      54540       8314               0       0      5
# 22541         0         42         42               0       0      4
# 22542         0          0          0               0       0      4
#
#        srv_count  protocol_type  service  flag
# 0              1              1       45     1
# 1              1              1       19     9
# 2             65              0       13     9
# 3              8              1       55     2
# 4              4              1       22     9
# ...          ...            ...      ...   ...
# 22538          1              1       49     9
# 22539         11              1       22     9
# 22540         10              1       22     9
# 22541          6              2       11     9
# 22542         10              1       52     1
#
# [22543 rows x 10 columns]

# %% [markdown]
# ## Evaluating Function

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
def evaluate_model(ytrue,ypred):
    print(f"Accuracy: {accuracy_score(ytrue,ypred)}")
    print(f"Precision: {precision_score(ytrue,ypred)}")
    print(f"Recall: {recall_score(ytrue,ypred)}")
    print(f"F1 Score: {f1_score(ytrue,ypred)}")

# %% [markdown]
# ## Model Evaluation

# %%
import joblib

# %%
model_dir=os.path.join(".","Models")

# %% [markdown]
# ## Evaluating Random Forest

# %%
path=os.path.join(model_dir,"random_forest.pkl")

# %%
model=joblib.load(path)

# %%
ypred=model.predict(test_data)
# Out:
# /home/amartya/.local/lib/python3.10/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
